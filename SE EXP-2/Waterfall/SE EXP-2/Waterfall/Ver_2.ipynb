# %% [markdown]
# <a href="https://colab.research.google.com/github/SujanVulasala/SOFTWARE-ENGINEERING/blob/main/SE%20EXP-2/Waterfall/Ver_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Waterfall Ver 2.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1XZ5ubEGDrLMuAx26r2fft_HOH4upS0WO
"""

def quadratic_model(a, b, c, x):
    return a * x**2 + b * x + c
print("Enter coefficients for Temperature (a, b, c):")
temp_coeffs = [float(input(f"Enter coefficient {coef}: ")) for coef in ['a', 'b', 'c']]
print("Enter coefficients for Rainfall (a, b, c):")
rainfall_coeffs = [float(input(f"Enter coefficient {coef}: ")) for coef in ['a', 'b', 'c']]
print("Enter coefficients for Humidity (a, b, c):")
humidity_coeffs = [float(input(f"Enter coefficient {coef}: ")) for coef in ['a', 'b', 'c']]
days = [1, 100, 200, 365]
temperature = [quadratic_model(*temp_coeffs, day) for day in days]
rainfall = [quadratic_model(*rainfall_coeffs, day) for day in days]
humidity = [quadratic_model(*humidity_coeffs, day) for day in days]
print("\nResults:")
print(f"Days: {days}")
print(f"Temperature: {temperature}")
print(f"Rainfall: {rainfall}")
print(f"Humidity: {humidity}")
# Out:
# Enter coefficients for Temperature (a, b, c):
# Enter coefficient a: 20
# Enter coefficient b: 24
# Enter coefficient c: 22
# Enter coefficients for Rainfall (a, b, c):
# Enter coefficient a: 13
# Enter coefficient b: 12
# Enter coefficient c: 10
# Enter coefficients for Humidity (a, b, c):
# Enter coefficient a: 12
# Enter coefficient b: 13
# Enter coefficient c: 14
#
# Results:
# Days: [1, 100, 200, 365]
# Temperature: [66.0, 202422.0, 804822.0, 2673282.0]
# Rainfall: [35.0, 131210.0, 522410.0, 1736315.0]
# Humidity: [39.0, 121314.0, 482614.0, 1603459.0]
